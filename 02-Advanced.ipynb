# %% [markdown]
# # Advanced Libraries

# %% [markdown]
# This notebook contains sample code using several advanced libraries that are highly useful for data science and machine learning.

# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# create a series
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0     1
# 1     3
# 2     5
# 3   NaN
# 4     6
# 5     8
# dtype: float64

# %%
# create a data frame
dates = pd.date_range('20130101',periods=6)
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.270376  1.750691  0.150835  0.324259
# 2013-01-02 -2.035858  0.827326  0.030431 -0.341746
# 2013-01-03 -0.015461 -1.125494  0.981033  0.093287
# 2013-01-04  1.459990  1.161114  0.702443  0.223747
# 2013-01-05  0.403795  0.583964 -0.522561  0.313328
# 2013-01-06 -1.190541  1.543457  3.302513 -1.055216
#
# [6 rows x 4 columns]

# %%
# another way to create a data frame
df2 = pd.DataFrame(
    { 'A' : 1.,
      'B' : pd.Timestamp('20130102'),
      'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
      'D' : np.array([3] * 4,dtype='int32'),
      'E' : 'foo' })
df2
# Out:
#    A          B  C  D    E
# 0  1 2013-01-02  1  3  foo
# 1  1 2013-01-02  1  3  foo
# 2  1 2013-01-02  1  3  foo
# 3  1 2013-01-02  1  3  foo
#
# [4 rows x 5 columns]

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.270376  1.750691  0.150835  0.324259
# 2013-01-02 -2.035858  0.827326  0.030431 -0.341746
# 2013-01-03 -0.015461 -1.125494  0.981033  0.093287
# 2013-01-04  1.459990  1.161114  0.702443  0.223747
# 2013-01-05  0.403795  0.583964 -0.522561  0.313328
#
# [5 rows x 4 columns]

# %%
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2013-01-01, ..., 2013-01-06]
# Length: 6, Freq: D, Timezone: None

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.27037586,  1.75069079,  0.15083514,  0.32425919],
#        [-2.03585788,  0.82732564,  0.03043113, -0.34174576],
#        [-0.01546129, -1.12549356,  0.98103317,  0.09328662],
#        [ 1.45998997,  1.16111385,  0.7024433 ,  0.22374726],
#        [ 0.40379519,  0.58396418, -0.52256141,  0.31332753],
#        [-1.19054065,  1.54345711,  3.30251314, -1.05521566]])

# %%
# quick data summary
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.184616  0.790176  0.774116 -0.073723
# std    1.243026  1.033568  1.346378  0.540323
# min   -2.035858 -1.125494 -0.522561 -1.055216
# 25%   -0.896771  0.644805  0.060532 -0.232988
# 50%    0.127457  0.994220  0.426639  0.158517
# 75%    0.370440  1.447871  0.911386  0.290932
# max    1.459990  1.750691  3.302513  0.324259
#
# [8 rows x 4 columns]

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.270376   -2.035858   -0.015461    1.459990    0.403795   -1.190541
# B    1.750691    0.827326   -1.125494    1.161114    0.583964    1.543457
# C    0.150835    0.030431    0.981033    0.702443   -0.522561    3.302513
# D    0.324259   -0.341746    0.093287    0.223747    0.313328   -1.055216
#
# [4 rows x 6 columns]

# %%
# axis 0 is index, axis 1 is columns
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.324259  0.150835  1.750691  0.270376
# 2013-01-02 -0.341746  0.030431  0.827326 -2.035858
# 2013-01-03  0.093287  0.981033 -1.125494 -0.015461
# 2013-01-04  0.223747  0.702443  1.161114  1.459990
# 2013-01-05  0.313328 -0.522561  0.583964  0.403795
# 2013-01-06 -1.055216  3.302513  1.543457 -1.190541
#
# [6 rows x 4 columns]

# %%
# can sort by values too
df.sort(columns='B')
# Out:
#                    A         B         C         D
# 2013-01-03 -0.015461 -1.125494  0.981033  0.093287
# 2013-01-05  0.403795  0.583964 -0.522561  0.313328
# 2013-01-02 -2.035858  0.827326  0.030431 -0.341746
# 2013-01-04  1.459990  1.161114  0.702443  0.223747
# 2013-01-06 -1.190541  1.543457  3.302513 -1.055216
# 2013-01-01  0.270376  1.750691  0.150835  0.324259
#
# [6 rows x 4 columns]

# %% [markdown]
# ### Selection

# %%
# select a column (yields a series)
df['A']
# Out:
# 2013-01-01    0.270376
# 2013-01-02   -2.035858
# 2013-01-03   -0.015461
# 2013-01-04    1.459990
# 2013-01-05    0.403795
# 2013-01-06   -1.190541
# Freq: D, Name: A, dtype: float64

# %%
# column names also attached to the object
df.A
# Out:
# 2013-01-01    0.270376
# 2013-01-02   -2.035858
# 2013-01-03   -0.015461
# 2013-01-04    1.459990
# 2013-01-05    0.403795
# 2013-01-06   -1.190541
# Freq: D, Name: A, dtype: float64

# %%
# slicing works
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.270376  1.750691  0.150835  0.324259
# 2013-01-02 -2.035858  0.827326  0.030431 -0.341746
# 2013-01-03 -0.015461 -1.125494  0.981033  0.093287
#
# [3 rows x 4 columns]

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -2.035858  0.827326  0.030431 -0.341746
# 2013-01-03 -0.015461 -1.125494  0.981033  0.093287
# 2013-01-04  1.459990  1.161114  0.702443  0.223747
#
# [3 rows x 4 columns]

# %%
# cross-section using a label
df.loc[dates[0]]
# Out:
# A    0.270376
# B    1.750691
# C    0.150835
# D    0.324259
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
# getting a scalar value
df.loc[dates[0], 'A']
# Out:
# 0.27037585728627589

# %%
# select via position
df.iloc[3]
# Out:
# A    1.459990
# B    1.161114
# C    0.702443
# D    0.223747
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04  1.459990  1.161114
# 2013-01-05  0.403795  0.583964
#
# [2 rows x 2 columns]

# %%
# column slicing
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01  1.750691  0.150835
# 2013-01-02  0.827326  0.030431
# 2013-01-03 -1.125494  0.981033
# 2013-01-04  1.161114  0.702443
# 2013-01-05  0.583964 -0.522561
# 2013-01-06  1.543457  3.302513
#
# [6 rows x 2 columns]

# %%
# get a value by index
df.iloc[1,1]
# Out:
# 0.82732563615181409

# %%
# boolean indexing
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.270376  1.750691  0.150835  0.324259
# 2013-01-04  1.459990  1.161114  0.702443  0.223747
# 2013-01-05  0.403795  0.583964 -0.522561  0.313328
#
# [3 rows x 4 columns]

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.270376  1.750691  0.150835  0.324259
# 2013-01-02       NaN  0.827326  0.030431       NaN
# 2013-01-03       NaN       NaN  0.981033  0.093287
# 2013-01-04  1.459990  1.161114  0.702443  0.223747
# 2013-01-05  0.403795  0.583964       NaN  0.313328
# 2013-01-06       NaN  1.543457  3.302513       NaN
#
# [6 rows x 4 columns]

# %%
# filtering
df3 = df.copy()
df3['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df3[df3['E'].isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.015461 -1.125494  0.981033  0.093287   two
# 2013-01-05  0.403795  0.583964 -0.522561  0.313328  four
#
# [2 rows x 5 columns]

# %%
# setting examples
df.at[dates[0],'A'] = 0
df.iat[0,1] = 0
df.loc[:, 'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000  0.150835  5
# 2013-01-02 -2.035858  0.827326  0.030431  5
# 2013-01-03 -0.015461 -1.125494  0.981033  5
# 2013-01-04  1.459990  1.161114  0.702443  5
# 2013-01-05  0.403795  0.583964 -0.522561  5
# 2013-01-06 -1.190541  1.543457  3.302513  5
#
# [6 rows x 4 columns]

# %%
# dealing with missing data
df4 = df.reindex(index=dates[0:4],columns=list(df.columns) + ['E'])
df4.loc[dates[0]:dates[1],'E'] = 1
df4
# Out:
#                    A         B         C  D   E
# 2013-01-01  0.000000  0.000000  0.150835  5   1
# 2013-01-02 -2.035858  0.827326  0.030431  5   1
# 2013-01-03 -0.015461 -1.125494  0.981033  5 NaN
# 2013-01-04  1.459990  1.161114  0.702443  5 NaN
#
# [4 rows x 5 columns]

# %%
# drop rows with missing data
df4.dropna(how='any')
# Out:
#                    A         B         C  D  E
# 2013-01-01  0.000000  0.000000  0.150835  5  1
# 2013-01-02 -2.035858  0.827326  0.030431  5  1
#
# [2 rows x 5 columns]

# %%
# fill missing data
df4.fillna(value=5)
# Out:
#                    A         B         C  D  E
# 2013-01-01  0.000000  0.000000  0.150835  5  1
# 2013-01-02 -2.035858  0.827326  0.030431  5  1
# 2013-01-03 -0.015461 -1.125494  0.981033  5  5
# 2013-01-04  1.459990  1.161114  0.702443  5  5
#
# [4 rows x 5 columns]

# %%
# boolean mask for nan values
pd.isnull(df4)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True
#
# [4 rows x 5 columns]

# %% [markdown]
# ### Operations

# %%
df.mean()
# Out:
# A   -0.229679
# B    0.498395
# C    0.774116
# D    5.000000
# dtype: float64

# %%
# pivot the mean calculation
df.mean(1)
# Out:
# 2013-01-01    1.287709
# 2013-01-02    0.955475
# 2013-01-03    1.210020
# 2013-01-04    2.080887
# 2013-01-05    1.366299
# 2013-01-06    2.163857
# Freq: D, dtype: float64

# %%
# aligning objects with different dimensions
s = pd.Series([1,3,5,np.nan,6,8],index=dates).shift(2)
df.sub(s,axis='index')
# Out:
#                    A         B         C   D
# 2013-01-01       NaN       NaN       NaN NaN
# 2013-01-02       NaN       NaN       NaN NaN
# 2013-01-03 -1.015461 -2.125494 -0.018967   4
# 2013-01-04 -1.540010 -1.838886 -2.297557   2
# 2013-01-05 -4.596205 -4.416036 -5.522561   0
# 2013-01-06       NaN       NaN       NaN NaN
#
# [6 rows x 4 columns]

# %%
# applying functions
df.apply(np.cumsum)
# Out:
#                    A         B         C   D
# 2013-01-01  0.000000  0.000000  0.150835   5
# 2013-01-02 -2.035858  0.827326  0.181266  10
# 2013-01-03 -2.051319 -0.298168  1.162299  15
# 2013-01-04 -0.591329  0.862946  1.864743  20
# 2013-01-05 -0.187534  1.446910  1.342181  25
# 2013-01-06 -1.378075  2.990367  4.644694  30
#
# [6 rows x 4 columns]

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    3.495848
# B    2.668951
# C    3.825075
# D    0.000000
# dtype: float64

# %%
# simple count aggregation
s = pd.Series(np.random.randint(0,7,size=10))
s.value_counts()
# Out:
# 5    2
# 1    2
# 0    2
# 6    1
# 4    1
# 3    1
# 2    1
# dtype: int64

# %% [markdown]
# ### Merging/Grouping/Shaping

# %%
# concatenation
df = pd.DataFrame(np.random.randn(10, 4))
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.106679 -1.598935 -2.728335  1.485140
# 1 -0.205480 -0.263223  0.691798  2.216294
# 2  0.264048  2.197087  0.616886 -0.427831
# 3 -1.294905 -0.671514  0.872133  0.269487
# 4  0.915000 -1.063805  1.030162 -0.027969
# 5  0.442543  0.886917 -0.997707  0.878672
# 6 -0.415647  0.345906 -1.847782 -0.619244
# 7  0.897627  1.612960  0.151089 -0.069049
# 8  3.409305  1.173007  0.663672 -0.306619
# 9 -2.680890 -0.010690  1.374825  0.846091
#
# [10 rows x 4 columns]

# %%
# SQL-style join
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5
#
# [4 rows x 3 columns]

# %%
# append
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  2.336517  1.365396 -0.496052  0.765892
# 1 -0.893650 -1.251260 -0.850533 -1.670657
# 2  0.434899  0.607334  1.489318  0.238080
# 3 -0.582976 -1.320815 -0.461228 -1.220741
# 4 -0.217072 -0.856358  0.191199 -1.129858
# 5 -0.950404  0.602901 -1.107613 -2.076151
# 6  0.935949  0.535069 -0.426108  0.547904
# 7  1.151556  0.173443  0.346158  0.396911
# 8 -0.582976 -1.320815 -0.461228 -1.220741
#
# [9 rows x 4 columns]

# %%
df = pd.DataFrame(
    { 'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
      'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
      'C' : np.random.randn(8),
      'D' : np.random.randn(8) })
df
# Out:
#      A      B         C         D
# 0  foo    one -1.377163 -0.231507
# 1  bar    one -1.836917 -0.666436
# 2  foo    two  0.956774 -0.028458
# 3  bar  three  1.613638 -0.670232
# 4  foo    two  2.353544  0.104867
# 5  bar    two  0.028034 -0.454470
# 6  foo    one -0.020411  0.785670
# 7  foo  three -0.169018  1.144714
#
# [8 rows x 4 columns]

# %%
# group by
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -0.195244 -1.791137
# foo  1.743726  1.775285
#
# [2 rows x 2 columns]

# %%
# group by multiple columns
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -1.836917 -0.666436
#     three  1.613638 -0.670232
#     two    0.028034 -0.454470
# foo one   -1.397574  0.554163
#     three -0.169018  1.144714
#     two    3.310318  0.076408
#
# [6 rows x 2 columns]

# %%
df = pd.DataFrame(
    { 'A' : ['one', 'one', 'two', 'three'] * 3,
      'B' : ['A', 'B', 'C'] * 4,
      'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
      'D' : np.random.randn(12),
      'E' : np.random.randn(12)} )
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -2.042151 -2.779801
# 1     one  B  foo -1.228608 -0.400090
# 2     two  C  foo -0.704949 -0.261391
# 3   three  A  bar  0.444207  0.291124
# 4     one  B  bar -1.804090 -0.440430
# 5     one  C  bar -0.999486 -0.115278
# 6     two  A  foo -1.567461  0.364343
# 7   three  B  foo  0.670707  1.171023
# 8     one  C  foo -1.573561  0.147240
# 9     one  A  bar -0.441537  0.295550
# 10    two  B  bar -0.408698 -0.935658
# 11  three  C  bar -0.005693 -0.281781
#
# [12 rows x 5 columns]

# %%
# pivot table
pd.pivot_table(df, values='D', rows=['A', 'B'], cols=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.441537 -2.042151
#       B -1.804090 -1.228608
#       C -0.999486 -1.573561
# three A  0.444207       NaN
#       B       NaN  0.670707
#       C -0.005693       NaN
# two   A       NaN -1.567461
#       B -0.408698       NaN
#       C       NaN -0.704949
#
# [9 rows x 2 columns]

# %% [markdown]
# ### Time Series

# %%
# time period resampling
rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min', how='sum')
# Out:
# 2012-01-01    25940
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31    1.004851
# 2012-02-29   -0.444509
# 2012-03-31    0.439594
# 2012-04-30   -1.568670
# 2012-05-31   -1.732536
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps.to_timestamp()
# Out:
# 2012-01-01    1.004851
# 2012-02-01   -0.444509
# 2012-03-01    0.439594
# 2012-04-01   -1.568670
# 2012-05-01   -1.732536
# Freq: MS, dtype: float64

# %% [markdown]
# ### Plotting

# %%
# time series plot
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
# plot with a data frame
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# ### Input/Output

# %%
# write to a csv file
df.to_csv('foo.csv', index=False)

# %%
# read file back in
path = r'C:\Users\John\Documents\IPython Notebooks\foo.csv'
newDf = pd.read_csv(path)
newDf.head()
# Out:
#           A         B         C         D
# 0  1.533602 -1.912169  0.846502 -0.009393
# 1  2.028934 -2.035850  1.020018  0.716059
# 2  1.999498 -2.454286 -1.512450  1.280418
# 3  0.950383 -2.429818 -2.971323  1.387416
# 4 -0.412518 -1.543572 -2.492762  2.649910
#
# [5 rows x 4 columns]

# %%
# remove the file
import os
os.remove(path)

# %%
# can also do Excel
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %%
newDf2 = pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
newDf2.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.533602 -1.912169  0.846502 -0.009393
# 2000-01-02  2.028934 -2.035850  1.020018  0.716059
# 2000-01-03  1.999498 -2.454286 -1.512450  1.280418
# 2000-01-04  0.950383 -2.429818 -2.971323  1.387416
# 2000-01-05 -0.412518 -1.543572 -2.492762  2.649910
#
# [5 rows x 4 columns]

# %%
os.remove('foo.xlsx')

# %% [markdown]
# ## Scikit-learn
